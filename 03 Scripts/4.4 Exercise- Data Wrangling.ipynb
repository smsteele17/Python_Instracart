# %% [markdown]
# # Data Wrangling and Subsets- Task for 4.4 is below at In [56]

# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %%
#Import Orders Data
df_ords = pd.read_csv(r'/Users/shelbysteele/Documents/Instacart Basket Anaysis-1022/02 Data/Original Data/4.3_orders_products/orders.csv', index_col = False)

#Import Products Data
df_prods = pd.read_csv(r'/Users/shelbysteele/Documents/Instacart Basket Anaysis-1022/02 Data/Original Data/4.3_orders_products/products.csv', index_col = False)

# %%
#Dropping eval_set column from the orders.csv
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
#updating the actual orders.csv dataframe without the eval_set column
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
#renaming the column from orders_dow to orders_day_of_week
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#updating data type from numeric to string
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
#Import departments.csv data
df_dep = pd.read_csv(r'/Users/shelbysteele/Documents/Instacart Basket Anaysis-1022/02 Data/Original Data/departments.csv', index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
#transposing df_dep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
#take the first row of df_dep_t for the header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
#setting header row as df_dep header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#creating a data dictionary from the df_dep_t_new dataframe
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
print(data_dict.get('19','13'))
# Out:
# {'department': 'snacks'}

# %%
df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks = df_prods[df_prods['department_id']==19]

# %%
df_snacks.head(25)
# Out:
#      product_id                                       product_name  aisle_id  \
# 0             1                         Chocolate Sandwich Cookies        61
# 15           16                      Mint Chocolate Flavored Syrup       103
# 24           25            Salted Caramel Lean Protein & Fiber Bar         3
# 31           32                      Nacho Cheese White Bean Chips       107
# 40           41        Organic Sourdough Einkorn Crackers Rosemary        78
# 55           56                         Healthy Pop Butter Popcorn        23
# 58           59               Medium Taqueria Style Chipotle Salsa        50
# 76           77                  Coconut Chocolate Chip Energy Bar         3
# 77           78                  Nutter Butter Cookie Bites Go-Pak        61
# 92           93                        Uncured Cracked Pepper Beef        23
# 101         102                              Danish Butter Cookies        61
# ...

# %%
df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]

# %%
df_snacks_2.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([19])]

# %%
df_snacks_3.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([17,18,19])]

# %%
df_snacks_3.head(25)
# Out:
#      product_id                                       product_name  aisle_id  \
# 0             1                         Chocolate Sandwich Cookies        61
# 13           14                     Fresh Scent Dishwasher Cleaner        74
# 14           15                           Overnight Diapers Size 6        56
# 15           16                      Mint Chocolate Flavored Syrup       103
# 24           25            Salted Caramel Lean Protein & Fiber Bar         3
# 31           32                      Nacho Cheese White Bean Chips       107
# 40           41        Organic Sourdough Einkorn Crackers Rosemary        78
# 47           48                      School Glue, Washable, No Run        87
# 55           56                         Healthy Pop Butter Popcorn        23
# 56           57                                    Flat Toothpicks       111
# 58           59               Medium Taqueria Style Chipotle Salsa        50
# ...

# %% [markdown]
# # 4.4 Task

# %%
#bring up all column names in the df_ords dataframe
df_ords.head()
# Out:
#   order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329        1             1                   2                  8
# 1  2398795        1             2                   3                  7
# 2   473747        1             3                   3                 12
# 3  2254736        1             4                   4                  7
# 4   431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#2: updating data type from numeric to string
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
#checking that it was properly executed
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %%
#3: changing column name w/out overwriting dataframe
df_ords.rename(columns = {'order_hour_of_day' : 'order_time_of_day'})
# Out:
#         order_id user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0        2539329       1             1                   2                  8
# 1        2398795       1             2                   3                  7
# 2         473747       1             3                   3                 12
# 3        2254736       1             4                   4                  7
# 4         431534       1             5                   4                 15
# ...          ...     ...           ...                 ...                ...
# 3421078  2266710  206209            10                   5                 18
# 3421079  1854736  206209            11                   4                 10
# 3421080   626363  206209            12                   1                 12
# 3421081  2977660  206209            13                   1                 12
# 3421082   272231  206209            14                   6                 14
#
#          days_since_prior_order
# ...

# %%
#4: What is the busiest time of day for placing orders? 
df_ords['order_hour_of_day'].describe()
# Out:
# count    3.421083e+06
# mean     1.345202e+01
# std      4.226088e+00
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.300000e+01
# 75%      1.600000e+01
# max      2.300000e+01
# Name: order_hour_of_day, dtype: float64

# %%
#changing order_hours_of_day from a float type to an interger for whole numbers
df_ords['order_hour_of_day'] = df_ords['order_hour_of_day'].astype('int')

# %%
#viewing column as new data type in descending order: 10 am is the busiest time with 288,418 orders
df_ords['order_hour_of_day'].value_counts(dropna =False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
#5: determine the value of 4 in the 'department_id'
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
#6: Subset of breakfast items: need to determine which value is assocated to breakfast
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
#using value 14 in subset command
df_breakfast = df_prods[df_prods['department_id']==14]

# %%
#items from the breakfast food list
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
#7: Items from Alcohol
df_alcohol = df_prods[df_prods['department_id']==5]

# %%
#alcohol list
df_alcohol
# Out:
#        product_id                               product_name  aisle_id  \
# 51             52                        Mirabelle Brut Rose       134
# 118           119                     Chardonnay Paso Robles        62
# 149           150                                  Brut Rosé       134
# 233           234                          Tennessee Whiskey       124
# 248           249             Pinot Grigio, California, 2010        62
# ...           ...                                        ...       ...
# 49548       49544                    Cabernet Sauvignon Wine        28
# 49566       49562              Blanc De Noirs Sparkling Wine       134
# 49610       49606                        Organic Natural Red        28
# 49665       49661                                      Porto       134
# 49688       49684  Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# 51                 5    14.4
# 118                5     5.5
# ...

# %%
# Item from Deli
df_deli = df_prods[df_prods['department_id']==20]

# %%
# items from the deli
df_deli
# Out:
#        product_id                                   product_name  aisle_id  \
# 48             49  Vegetarian Grain Meat Sausages Italian - 4 CT        14
# 61             62        Premium Deli Oven Roasted Turkey Breast        96
# 73             74                Artisan Chick'n & Apple Sausage        14
# 84             85                           Soppressata Piccante        96
# 108           109                         Grape Leaf Hummus Wrap        13
# ...           ...                                            ...       ...
# 49558       49554                          Roasted Garlic Hommus        67
# 49564       49560    Selects Natural Slow Roasted Chicken Breast        96
# 49585       49581                   Pinto Bean and Cheese Pupusa        13
# 49609       49605                     Classic Hummus Family Size        67
# 49642       49638           Organic Superfirm Vacuum Packed Tofu        14
#
#        department_id  prices
# 48                20    10.1
# ...

# %%
#Items from the beverages
df_beverages = df_prods[df_prods['department_id']==7]

# %%
#items from beverages
df_beverages
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 19             20  Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# ...           ...                                             ...       ...
# 49659       49655                                     Apple Cider        98
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
#
#        department_id  prices
# ...

# %%
#Items from the meat & seafood
df_meat_seafood = df_prods[df_prods['department_id']==12]

# %%
#items from meat/seafood
df_meat_seafood
# Out:
#        product_id                                       product_name  \
# 16             17                                  Rendered Duck Fat
# 22             23                             Organic Turkey Burgers
# 34             35     Italian Herb Porcini Mushrooms Chicken Sausage
# 39             40  Beef Hot Links Beef Smoked Sausage With Chile ...
# 83             84                                         Lamb Shank
# ...           ...                                                ...
# 49425       49421                                   Salame, Peppered
# 49440       49436                              Imitation Crab Flakes
# 49509       49505                                Hot Italian Sausage
# 49655       49651                                       Beef Brisket
# 49674       49670                                Beef Summer Sausage
#
#        aisle_id  department_id  prices
# 16           35             12    17.1
# 22           49             12     8.2
# ...

# %%
#all dinner party items combined
df_dinner_party = df_prods.loc[df_prods['department_id'].isin([5,20,7,12])]

# %%
#dinner Party dataframe
df_dinner_party
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
#8: How many rows foes the dinner_party dataframe have?
df_dinner_party.shape
# Out:
# (7650, 5)

# %%
#9 extracting information about user_id '1' 
df_ords.head(11)
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
# 5   3367565       1             6                   2                  7
# 6    550135       1             7                   1                  9
# 7   3108588       1             8                   1                 14
# 8   2295261       1             9                   1                 16
# 9   2550362       1            10                   4                  8
# 10  1187899       1            11                   4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %%
#defined user_1 based on command
df_ords_user_1 = df_ords.head(11)

# %%
#details and basic stats on User_1
df_ords_user_1.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count     11.000000           11.000000          11.000000
# mean       6.000000            2.636364          10.090909
# std        3.316625            1.286291           3.477198
# min        1.000000            1.000000           7.000000
# 25%        3.500000            1.500000           7.500000
# 50%        6.000000            3.000000           8.000000
# 75%        8.500000            4.000000          13.000000
# max       11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
#12: export df_ords dataframe
df_ords.to_csv(r'/Users/shelbysteele/Documents/Instacart Basket Anaysis-1022/02 Data/Prepared Data/orders_wrangled.csv')

# %%
#13: Export the df_dep_t_new dataframe
df_dep_t_new.to_csv(r'/Users/shelbysteele/Documents/Instacart Basket Anaysis-1022/02 Data/Prepared Data/department_wrangled.csv')
